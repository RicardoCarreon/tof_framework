# %% [markdown]
# # Image processing notebook: from Transmission images to ROI-specific cross-section plots
#
# ### 00 - Introduction
#
#
# ### Applied processing
# The following processing parts
#
# - Select directories of transmission images
# - display the image (average as default, but the sum is also available)
# - adjust contrast, brightness, saturation, apply color LUTs to better analyze the image
# - apply zoom in a specific region (2 images side-by side, the right one has the zoom and the right one the region selected) [it displays the x,y,w,h info]
# - Select several ROIs, you can manually type them too (add a string of values)
# - give the names or mantain them as default (ROI_1, ROI_2, etc)
# - print the image with the ROIs selected with the names
# - select the graph you want to print
# - plot the cross-sections
# - have a file in excel with a pandas database with the transmission information (name of the sample

# %% [markdown]
# ## initial settings

# %% [markdown]
# ### import libraries

# %%
import sys
sys.path.append(r'..\framework')
sys.path.append(r'..\proc_functions')
sys.path.append(r'..\utilities')
from stack_proc_func import *
from img_utils_4_transmission import *
from plot_cross_sections import *
# %matplotlib inline

# %% [markdown]
# ### provide directories

# %% [markdown]
# #### Provide the directory where the transmission images are saved

# %%
# %load select_directory('src_dir')
src_dir = r"C:\Users\carreon_r\Documents\IP_Python\ICON20202063\exp017_poin17C\Processed_during BT\Transmission_results"

# %% [markdown]
# #### Provide the Spectra.txt file from any of the experiments. These are the neutron arrival times the MCP detected

# %%
# %load select_file('spectra_file')
spectra_file = r"C:\Users\carreon_r\Documents\IP_Python\ICON20202063\exp017_poin17C\ordered_exp201\03_ob\exp201_001_Spectra.txt"

# %% [markdown]
# #### Provide the directory where the casing transmission images are saved

# %%
# %load select_directory('casing_dir')
casing_dir = r"C:\Users\carreon_r\Documents\IP_Python\ICON20202063\exp017_poin17C\Processed_during BT\Transmission_results"

# %%
flight_path = 5.45

# %% [markdown]
# ### Select the folder where the casing transmission images are saved

# %%
casing_dict = prep_stack_dict(casing_dir)
casing_images = avg_transmission_img(casing_dict, ['07_batch03_temp17C'], save_results = False)
# Out:
# Averaging:   0%|                                         | 0/1 [00:00<?, ?it/s]
# save_results = False
# Averaging: 100%|█████████████████████████████████| 1/1 [00:04<00:00,  4.63s/it]

# %% [markdown]
# #### Select the ROI which corresponds to the casing

# %%
# %load select_multiple_rois('07_batch03_temp17C', casing_images[0])
ROIs_07_batch03_temp17C = [[57, 289, 242, 61]]

# %% [markdown]
# #### Display the average of the casing transmission Images

# %%
show_img(casing_images[0], dr = [(ROIs_07_batch03_temp17C, 'yellow')], cmap='gray')

# %% [markdown]
# #### Create the dictionary with the folder contaiming the casing to process

# %%
rois_dict_casing = {}
for name in ['07_batch03_temp17C']:
    rois_name = 'ROIs_'+ name
    for rois in [rois_name]:
        rois_dict_casing[rois] = eval(rois)

# %% [markdown]
# #### Get the casing transmission values to include them in the process

# %%
raw_trans_val_casing = get_transmission_values (casing_dict, rois_dict_casing, spectra_file, src_dir=src_dir,  binning = 1, 
                                         flight_path = flight_path, start_slice=1, end_slice = 100, save_results = False,
                                         name_xlsx = 'Transmission_values_casing.xlsx')

# %% [markdown]
# ### Select folders with the samples to process

# %%
imgs_dict = prep_stack_dict(src_dir)
for key in imgs_dict.keys():
    print(key)
# Out:
# 05_batch01_temp17C
# 06_batch02_temp17C
# 07_batch03_temp17C

# %% [markdown]
# #### add the folders you are interested in

# %%
#proc_folder = []
proc_folder = ['05_batch01_temp17C', '06_batch02_temp17C','07_batch03_temp17C']

# %%
avg_images = avg_transmission_img(imgs_dict, proc_folder, save_results = False)
# Out:
# Averaging:   0%|                                         | 0/1 [00:00<?, ?it/s]
# save_results = False
# Averaging: 100%|█████████████████████████████████| 1/1 [00:03<00:00,  3.35s/it]
# Averaging: 100%|█████████████████████████████████| 1/1 [00:03<00:00,  3.78s/it]
# Averaging: 100%|█████████████████████████████████| 1/1 [00:00<00:00,  2.50it/s]

# %% [markdown]
# to use effectively the magic of %load, the selection of ROIs is required to be done separately per image. In this way we save the ROIs selected for the documentation

# %% [markdown]
# no need to specify the processing folders again because the functions before, remove the "undesire" folders from the dictionary

# %%
# %load select_multiple_rois(proc_folder[0], avg_images [0], cmap = 'flag')
ROIs_05_batch01_temp17C = [[54, 430, 230, 63], [54, 293, 229, 61], [56, 159, 227, 60], [53, 22, 230, 60]]

# %%
show_img(avg_images[0], dr = [(ROIs_05_batch01_temp17C, 'yellow')], cmap='gray')

# %%
# %load select_multiple_rois(proc_folder[1], avg_images [1],cmap='flag')
ROIs_06_batch02_temp17C = [[57, 427, 235, 61], [56, 288, 238, 60], [53, 152, 239, 62], [52, 16, 242, 60]]

# %%
show_img(avg_images[1], dr = [(ROIs_06_batch02_temp17C, 'yellow')], cmap='gray')

# %%
# %load select_multiple_rois(proc_folder[2], avg_images [2],cmap='flag')
ROIs_07_batch03_temp17C = [[57, 427, 235, 61], [53, 152, 239, 62], [52, 16, 242, 60]]

# %%
show_img(avg_images[2], dr = [(ROIs_07_batch03_temp17C, 'yellow')], cmap='gray')

# %% [markdown]
# Because (for documentation reasons) the ROIs were selected separately. A dictionary is automatic created containing all the ROIs that were selected
#
# the automatic process is the following:
#
# new_dict = {}
# for folder,image in zip(proc_folder,avg_images):
#     new_dict[folder] =select_multiple_rois(folder, image, just_rois=True)
#     show_img(image, dr = [(new_dict.get(folder), 'yellow')], cmap='flag')
#
# %load keep_roi_values_dict(new_dict)
#
# However, it does not fit the documentation purpose and can only be used if you are sure the ROIs will never change

# %%
rois_dict = {}
for name in proc_folder:
    rois_name = 'ROIs_'+ name
    for rois in [rois_name]:
        rois_dict[rois] = eval(rois)

# %% [markdown]
# When you selected the folders you wanted to process, the program got rid of usless information. For this reason, the original dictionary "imgs_dict" will contain only the selcted folders and can be used directly in the next function

# %%
raw_trans_val = get_transmission_values (imgs_dict, rois_dict, spectra_file, src_dir=src_dir,  binning = 1, 
                                         flight_path = flight_path, start_slice=1, end_slice = 100, save_results = False,
                                         name_xlsx = 'Transmission_values.xlsx')

# %%
print(raw_trans_val)
# Out:
#     Wavelength [Å]  raw_trans_05_batch01_temp17C_roi_1  \
# 0         0.130658                            0.461591
# 1         0.188728                            0.460111
# 2         0.246798                            0.458564
# 3         0.304869                            0.457819
# 4         0.362939                            0.454829
# ..             ...                                 ...
# 94        6.409675                            0.272474
# 95        6.467745                            0.275460
# 96        6.525816                            0.276296
# 97        6.583886                            0.280520
# 98        6.641956                            0.286165
#
#     raw_trans_05_batch01_temp17C_roi_2  raw_trans_05_batch01_temp17C_roi_3  \
# 0                             0.439006                            0.416178
# 1                             0.436785                            0.413427
# 2                             0.434968                            0.410975
# 3                             0.431942                            0.406930
# 4                             0.429998                            0.406007
# ..                                 ...                                 ...
# 94                            0.265834                            0.245622
# 95                            0.270710                            0.250753
# 96                            0.274057                            0.255233
# 97                            0.279412                            0.259551
# 98                            0.283581                            0.264525
#
#     raw_trans_05_batch01_temp17C_roi_4  raw_trans_06_batch02_temp17C_roi_1  \
# 0                             0.451896                            0.450802
# 1                             0.449253                            0.448801
# 2                             0.446854                            0.445581
# 3                             0.443414                            0.442562
# 4                             0.441713                            0.443305
# ..                                 ...                                 ...
# 94                            0.325110                            0.267966
# 95                            0.328581                            0.269665
# 96                            0.334120                            0.269505
# 97                            0.340237                            0.276392
# 98                            0.340740                            0.279737
#
#     raw_trans_06_batch02_temp17C_roi_2  raw_trans_06_batch02_temp17C_roi_3  \
# 0                             0.429058                            0.408800
# 1                             0.427317                            0.406485
# 2                             0.424858                            0.404460
# 3                             0.421830                            0.400785
# 4                             0.420479                            0.399552
# ..                                 ...                                 ...
# 94                            0.265870                            0.249186
# 95                            0.267045                            0.251937
# 96                            0.274776                            0.256718
# 97                            0.274930                            0.260802
# 98                            0.282774                            0.269701
#
#     raw_trans_06_batch02_temp17C_roi_4  raw_trans_07_batch03_temp17C_roi_1  \
# 0                             0.437863                            0.398472
# 1                             0.436413                            0.396949
# 2                             0.433253                            0.393868
# 3                             0.430701                            0.391525
# 4                             0.429656                            0.389973
# ..                                 ...                                 ...
# 94                            0.259046                            0.219246
# 95                            0.260950                            0.223560
# 96                            0.268750                            0.224415
# 97                            0.273195                            0.228703
# 98                            0.281005                            0.230262
#
#     raw_trans_07_batch03_temp17C_roi_2  raw_trans_07_batch03_temp17C_roi_3
# 0                             0.373399                            0.328815
# 1                             0.369677                            0.325544
# 2                             0.367500                            0.322110
# 3                             0.363759                            0.318874
# 4                             0.360530                            0.313702
# ..                                 ...                                 ...
# 94                            0.233109                            0.181495
# 95                            0.238463                            0.186418
# 96                            0.244137                            0.196059
# 97                            0.248951                            0.199673
# 98                            0.255685                            0.206057
#
# [99 rows x 12 columns]

# %%
h2o = {'abbv': 'H2O','composition' : {'H':2.0, 'O':1.0},'density':0.997, 'thickness': 0.3}
ec = {'abbv': 'EC', 'composition' : {'C':3.0, 'H':4.0, 'O':3.0},'density':1.32, 'thickness': 0.3}
dmc = {'abbv': 'DMC','composition' : {'C':3.0, 'H':6.0, 'O':3.0}, 'density':1.07, 'thickness': 0.3}
dec = {'abbv': 'DEC','composition' : {'C':5.0, 'H':10.0, 'O':3.0}, 'density':0.975, 'thickness': 0.3}
lipf6 = {'abbv': 'LiPF6','composition' : {'LI':1.0, 'P':1.0, 'F':6.0}, 'density':1.5, 'thickness': 0.3}
ec_dmc_11v = {'abbv': 'EC_DMC (1:1v)','molecules' : [ec,0.5,dmc,0.5], 'density':1.28, 'thickness': 0.3 }
ec_dmc_11w = {'abbv': 'EC_DMC (1:1w)','molecules' : [ec,0.447511501,dmc,0.552488499], 'density':1.2335, 'thickness': 0.3 }
ec_dec_11v = {'abbv': 'EC_DEC (1:1v)','molecules' : [ec,0.5,dec,0.5], 'density':1.1785, 'thickness': 0.3 }
ec_dec_37w = {'abbv': 'EC_DEC (3:7w)','molecules' : [ec,0.240305619,dec,0.759694381], 'density':1.0705, 'thickness': 0.3 }
lp30 = {'abbv': 'LP30','molecules' : [ec, 0.406359477,dmc, 0.501683056, lipf6, 0.091957467], 'density':1.2795, 'thickness': 0.3}
lp40 = {'abbv': 'LP40','molecules' : [ec, 0.447925137,dec, 0.447925137, lipf6, 0.104149725], 'density':1.2635, 'thickness': 0.3}
lp47 = {'abbv': 'LP47','molecules' : [ec, 0.218207723,dec, 0.689834809, lipf6 ,0.091957467], 'density':1.1685, 'thickness': 0.3}
ec_dec_sol = {'abbv': 'EC_DEC (sol)','molecules' : [ec,0.5,dec,0.5], 'density':1.1785, 'thickness': 0.3 }
pe = {'abbv': 'PE', 'composition' : {'C':1.0, 'H':2.0},'density':0.92, 'thickness': 0.2}

# %%
compounds_dict = [lp30,lp40,lp47,ec,ec_dmc_11v,ec_dec_11v, ec_dec_37w,dmc,dec,pe,h2o]

# %% [markdown]
# Function to get the cross sections, the requested_cs is a list of the desired cross-sections oprions are ['total_cs','h_cs','lli_cs']

# %%
requested_cs = ['total_cs','h_cs']
cs_table = get_cross_sections (raw_trans_val, raw_trans_val_casing, compounds_dict, requested_cs , 
                               dst_dir = src_dir, save_table = True, name_xlsx = 'TEST_ICON_CS_results.xlsx')

# %%
print(cs_table)
# Out:
#     Wavelength [Å]  CS_tot_LP30  CS_H_in_LP30  CS_tot_LP40  CS_H_in_LP40  \
# 0         0.130658   285.021460     55.715222   347.139562     56.866527
# 1         0.188728   286.590541     56.053425   349.815910     57.346207
# 2         0.246798   287.857536     56.326516   351.638439     57.672858
# 3         0.304869   289.049750     56.575653   355.580176     58.371064
# 4         0.362939   291.409272     57.046879   357.266599     58.633785
# ..             ...          ...           ...          ...           ...
# 94        6.409675   517.249988     99.657817   597.866432     95.591914
# 95        6.467745   514.644508     99.019947   591.394865     94.355779
# 96        6.525816   512.856728     98.558326   584.889715     93.113625
# 97        6.583886   503.614988     96.490722   572.397182     90.799059
# 98        6.641956   496.048103     94.785064   566.301172     89.632004
#
#     CS_tot_LP47  CS_H_in_LP47   CS_tot_EC  CS_H_in_EC  CS_tot_EC_DMC (1:1v)  \
# 0    432.182836     56.383563  254.241263   57.153976            284.676346
# 1    436.159386     56.944242  256.576952   57.737898            286.698260
# 2    439.269055     57.382694  258.406433   58.195269            289.499921
# 3    445.468293     58.250069  261.689850   59.015266            292.781041
# 4    446.165497     58.316417  262.730681   59.272505            291.667369
# ..          ...           ...         ...         ...                   ...
# 94   737.105355     94.249128  381.945144   86.200813            505.811254
# 95   728.206400     92.930998  379.796398   85.616385            505.185334
# 96   717.629684     91.376311  373.196593   83.919193            504.954204
# 97   704.597328     89.475952  364.109324   81.600135            491.893115
# 98   695.195107     88.088269  364.380870   81.620275            487.848485
#
#     ...  CS_tot_EC_DEC (3:7w)  CS_H_in_EC_DEC (3:7w)  CS_tot_DMC  CS_H_in_DMC  \
# 0   ...            442.221036              52.564233  335.522182    51.649471
# 1   ...            445.662759              53.004869  337.281563    51.942701
# 2   ...            448.237847              53.334553  340.481591    52.476039
# 3   ...            454.008177              54.072759  343.777246    53.024743
# 4   ...            455.160589              54.218370  344.430365    53.131617
# ..  ...                   ...                    ...         ...          ...
# 94  ...            729.044332              87.424508  587.818664    91.779462
# 95  ...            725.580202              86.950568  586.644347    91.552248
# 96  ...            714.392256              85.487763  572.380773    89.143492
# 97  ...            701.916507              83.860084  561.724099    87.335886
# 98  ...            684.346457              81.579872  549.619573    85.286634
#
#     CS_tot_DEC  CS_H_in_DEC   CS_tot_PE  CS_H_in_PE  CS_tot_H2O  CS_H_in_H2O
# 0   546.110076    51.099506  111.308345   53.281758  100.659861    48.431452
# 1   548.985266    51.387025  112.634627   53.944899  101.705728    48.954386
# 2   553.942208    51.882719  113.331644   54.293407  102.726186    49.464615
# 3   558.725483    52.360558  114.774381   55.014411  103.852486    50.027558
# 4   560.700285    52.556348  115.772931   55.512428  105.385451    50.793319
# ..         ...          ...         ...         ...         ...          ...
# 94  957.868885    90.648200  173.042627   82.960065  161.749036    78.245452
# 95  948.021005    89.636839  170.775648   81.807384  159.552797    77.135030
# 96  944.687258    89.276891  167.652479   80.226607  154.394068    74.543363
# 97  927.654680    87.547060  164.362168   78.562260  151.920640    73.294347
# 98  924.583234    87.213065  161.263611   76.993602  148.994236    71.818693
#
# [99 rows x 23 columns]
