# %% [markdown]
# # Image processing notebook: from Transmission images to ROI-specific cross-section plots
#
# ### 00 - Introduction
#
#
# ### Applied processing
# The following processing parts
#
# - Select directories of transmission images
# - display the image (average as default, but the sum is also available)
# - adjust contrast, brightness, saturation, apply color LUTs to better analyze the image
# - apply zoom in a specific region (2 images side-by side, the right one has the zoom and the right one the region selected) [it displays the x,y,w,h info]
# - Select several ROIs, you can manually type them too (add a string of values)
# - give the names or mantain them as default (ROI_1, ROI_2, etc)
# - print the image with the ROIs selected with the names
# - select the graph you want to print
# - plot the cross-sections
# - have a file in excel with a pandas database with the transmission information (name of the sample

# %% [markdown]
# ## initial settings

# %% [markdown]
# ### import libraries

# %%
import sys
sys.path.append(r'..\framework')
sys.path.append(r'..\proc_functions')
sys.path.append(r'..\utilities')
from stack_proc_func import *
from img_utils_4_transmission import *
from plot_cross_sections import *
# %matplotlib inline

# %% [markdown]
# ### provide directories

# %% [markdown]
# #### Provide the directory where the transmission images are saved

# %%
# %load select_directory('src_dir')
src_dir = r"H:\700 Campaigns - internal\780 2020\PSI20_01NI\temp\IP_Yvette_02\Transmission_results_new"

# %% [markdown]
# #### Provide the Spectra.txt file from any of the experiments. These are the neutron arrival times the MCP detected

# %%
# %load select_file('spectra_file')
spectra_file = r"H:\700 Campaigns - internal\780 2020\PSI20_01NI\arch\100_Images\100_raw\08_yvette1\01_p1\IMAT00015384_08_yvette1_01_p1_000_Spectra.txt"

# %% [markdown]
# #### Provide the directory where the casing transmission images are saved

# %%
# %load select_directory('casing_dir')

# %%
flight_path = 5.45

# %% [markdown]
# ### Select the folder where the casing transmission images are saved

# %%
casing_dict = prep_stack_dict(casing_dir)
for key in casing_dict.keys():
    print(key)
# Out:
# 003_temp_00_p20_batch01
# 004_temp_00_p20_batch02
# 005_temp_00_p20_batch03
# 007_temp_01_p10_batch01
# 008_temp_01_p10_batch02
# 009_temp_01_p10_batch03
# 011_temp_02_p0_batch01
# 012_temp_02_p0_batch02
# 013_temp_02_p0_batch03
# 015_temp_03_m10_batch01
# 016_temp_03_m10_batch02
# 017_temp_03_m10_batch03
# 019_temp_04_m23_batch01
# 020_temp_04_m23_batch02
# 021_temp_04_m23_batch03
# 023_temp_05_m15_batch01
# 024_temp_05_m15_batch02
# 025_temp_05_m15_batch03
# 027_temp_06_m5_batch01
# 028_temp_06_m5_batch02
# 029_temp_06_m5_batch03
# 031_temp_07_p5_batch01
# 032_temp_07_p5_batch02
# 033_temp_07_p5_batch03
# 035_temp_08_p17_batch01
# 036_temp_08_p17_batch02
# 037_temp_08_p17_batch03
# 039_temp_09_p30_batch01
# 040_temp_09_p30_batch02
# 041_temp_09_p30_batch03
# 043_temp_10_p40_batch01
# 044_temp_10_p40_batch02
# 045_temp_10_p40_batch03
# 047_temp_11_p51_batch01
# 048_temp_11_p51_batch02
# 049_temp_11_p51_batch03
# 051_temp_12_p20_batch01
# 052_temp_12_p20_batch02
# 053_temp_12_p20_batch03
# 055_temp_13_p5_batch01
# 056_temp_13_p5_batch02
# 057_temp_13_p5_batch03
# 059_temp_14_m5_batch01
# 060_temp_14_m5_batch02
# 061_temp_14_m5_batch03
# 063_temp_15_m15_batch01
# 064_temp_15_m15_batch02
# 065_temp_15_m15_batch03

# %%
casing_folder = '037_temp_08_p17_batch03'
casing_images = avg_transmission_img(casing_dict, [casing_folder], save_results = False)
# Out:
# Averaging:   0%|                                         | 0/1 [00:00<?, ?it/s]
# save_results = False
# Averaging: 100%|█████████████████████████████████| 1/1 [00:00<00:00,  2.60it/s]

# %% [markdown]
# #### Select the ROI which corresponds to the casing

# %%
# %load select_multiple_rois(casing_folder, casing_images[0], cmap='gray')
ROIs_037_temp_08_p17_batch03 = [[112, 288, 188, 70]]

# %% [markdown]
# #### Display the average of the casing transmission Images

# %%
show_img(casing_images[0], dr = [(ROIs_037_temp_08_p17_batch03, 'blue')], cmap='gray')

# %% [markdown]
# #### Create the dictionary with the folder contaiming the casing to process

# %%
rois_dict_casing = {}
for name in [casing_folder]:
    rois_name = 'ROIs_'+ name
    for rois in [rois_name]:
        rois_dict_casing[rois] = eval(rois)

# %% [markdown]
# #### Get the casing transmission values to include them in the process

# %%
raw_trans_val_casing = get_transmission_values (casing_dict, rois_dict_casing, spectra_file, src_dir=src_dir,  binning = 1, 
                                         flight_path = flight_path, start_slice=1, end_slice = 100, save_results = False,
                                         name_xlsx = 'Transmission_values_casing.xlsx')

# %% [markdown]
# ### Select folders with the samples to process

# %%
imgs_dict = prep_stack_dict(src_dir)
for key in imgs_dict.keys():
    print(key)
# Out:
# 003_temp_00_p20_batch01
# 004_temp_00_p20_batch02
# 005_temp_00_p20_batch03
# 007_temp_01_p10_batch01
# 008_temp_01_p10_batch02
# 009_temp_01_p10_batch03
# 011_temp_02_p0_batch01
# 012_temp_02_p0_batch02
# 013_temp_02_p0_batch03
# 015_temp_03_m10_batch01
# 016_temp_03_m10_batch02
# 017_temp_03_m10_batch03
# 019_temp_04_m23_batch01
# 020_temp_04_m23_batch02
# 021_temp_04_m23_batch03
# 023_temp_05_m15_batch01
# 024_temp_05_m15_batch02
# 025_temp_05_m15_batch03
# 027_temp_06_m5_batch01
# 028_temp_06_m5_batch02
# 029_temp_06_m5_batch03
# 031_temp_07_p5_batch01
# 032_temp_07_p5_batch02
# 033_temp_07_p5_batch03
# 035_temp_08_p17_batch01
# 036_temp_08_p17_batch02
# 037_temp_08_p17_batch03
# 039_temp_09_p30_batch01
# 040_temp_09_p30_batch02
# 041_temp_09_p30_batch03
# 043_temp_10_p40_batch01
# 044_temp_10_p40_batch02
# 045_temp_10_p40_batch03
# 047_temp_11_p51_batch01
# 048_temp_11_p51_batch02
# 049_temp_11_p51_batch03
# 051_temp_12_p20_batch01
# 052_temp_12_p20_batch02
# 053_temp_12_p20_batch03
# 055_temp_13_p5_batch01
# 056_temp_13_p5_batch02
# 057_temp_13_p5_batch03
# 059_temp_14_m5_batch01
# 060_temp_14_m5_batch02
# 061_temp_14_m5_batch03
# 063_temp_15_m15_batch01
# 064_temp_15_m15_batch02
# 065_temp_15_m15_batch03

# %% [markdown]
# #### add the folders you are interested in

# %%
#proc_folder1 = [key for key in imgs_dict.keys() if 'batch01' in key]
#proc_folder2 = [key for key in imgs_dict.keys() if 'batch02' in key]
#proc_folder3 = [key for key in imgs_dict.keys() if 'batch03' in key]
proc_folder = ['003_temp_00_p20_batch01', '004_temp_00_p20_batch02','005_temp_00_p20_batch03']

# %%
imgs_dict = prep_stack_dict(src_dir)
avg_images = avg_transmission_img(imgs_dict, proc_folder, save_results = False)
# Out:
# Averaging:   0%|                                         | 0/1 [00:00<?, ?it/s]
# save_results = False
# Averaging: 100%|█████████████████████████████████| 1/1 [00:02<00:00,  2.46s/it]
# Averaging: 100%|█████████████████████████████████| 1/1 [00:02<00:00,  2.57s/it]
# Averaging: 100%|█████████████████████████████████| 1/1 [00:02<00:00,  2.55s/it]

# %% [markdown]
# to use effectively the magic of %load, the selection of ROIs is required to be done separately per image. In this way we save the ROIs selected for the documentation

# %% [markdown]
# no need to specify the processing folders again because the functions before, remove the "undesire" folders from the dictionary

# %%
# %load select_multiple_rois(proc_folder[0], avg_images[0], cmap = 'flag')
ROIs_003_temp_00_p20_batch01 = [[61, 438, 234, 51], [64, 298, 230, 51], [64, 163, 220, 51], [187, 23, 104, 51]]

# %%
show_img(avg_images[0], dr = [(ROIs_003_temp_00_p20_batch01, 'yellow')], cmap='gray')

# %%
# %load select_multiple_rois(proc_folder[1], avg_images[1],cmap='flag')
ROIs_004_temp_00_p20_batch02 = [[55, 439, 237, 51], [57, 298, 236, 51], [53, 163, 243, 51], [58, 23, 237, 51]]

# %%
show_img(avg_images[1], dr = [(ROIs_004_temp_00_p20_batch02, 'yellow')], cmap='gray')

# %%
# %load select_multiple_rois(proc_folder[2], avg_images[2],cmap='gray')
ROIs_005_temp_00_p20_batch03 = [[60, 438, 238, 51], [55, 164, 232, 51], [55, 23, 238, 51]]

# %%
show_img(avg_images[2], dr = [(ROIs_005_temp_00_p20_batch03, 'yellow')], cmap='gray')

# %% [markdown]
# Because (for documentation reasons) the ROIs were selected separately. A dictionary is automatic created containing all the ROIs that were selected
#
# the automatic process is the following:
#
# new_dict = {}
# for folder,image in zip(proc_folder,avg_images):
#     new_dict[folder] =select_multiple_rois(folder, image, just_rois=True)
#     show_img(image, dr = [(new_dict.get(folder), 'yellow')], cmap='flag')
#
# %load keep_roi_values_dict(new_dict)
#
# However, it does not fit the documentation purpose and can only be used if you are sure the ROIs will never change

# %%
rois_dict = {}
for name in proc_folder:
    rois_name = 'ROIs_'+ name
    for rois in [rois_name]:
        rois_dict[rois] = eval(rois)

# %% [markdown]
# When you selected the folders you wanted to process, the program got rid of usless information. For this reason, the original dictionary "imgs_dict" will contain only the selcted folders and can be used directly in the next function

# %%
raw_trans_val = get_transmission_values (imgs_dict, rois_dict, spectra_file, src_dir=src_dir,  binning = 1, 
                                         flight_path = flight_path, start_slice=1, end_slice = 100, save_results = False,
                                         name_xlsx = 'Transmission_values.xlsx')

# %%
print(raw_trans_val)
# Out:
#     Wavelength [Å]  raw_trans_003_temp_00_p20_batch01_roi_1  \
# 0         0.130658                                 0.376923
# 1         0.188728                                 0.380442
# 2         0.246798                                 0.387821
# 3         0.304869                                 0.390149
# 4         0.362939                                 0.392632
# ..             ...                                      ...
# 94        6.409675                                 0.225119
# 95        6.467745                                 0.223778
# 96        6.525816                                 0.220243
# 97        6.583886                                 0.221185
# 98        6.641956                                 0.220222
#
#     raw_trans_003_temp_00_p20_batch01_roi_2  \
# 0                                  0.359299
# 1                                  0.364318
# 2                                  0.365412
# 3                                  0.368857
# 4                                  0.372239
# ..                                      ...
# 94                                 0.210810
# 95                                 0.208856
# 96                                 0.204179
# 97                                 0.201628
# 98                                 0.205764
#
#     raw_trans_003_temp_00_p20_batch01_roi_3  \
# 0                                  0.342803
# 1                                  0.345772
# 2                                  0.347205
# 3                                  0.347217
# 4                                  0.350614
# ..                                      ...
# 94                                 0.187082
# 95                                 0.182993
# 96                                 0.182947
# 97                                 0.181437
# 98                                 0.178528
#
#     raw_trans_003_temp_00_p20_batch01_roi_4  \
# 0                                  0.368555
# 1                                  0.368058
# 2                                  0.375324
# 3                                  0.369875
# 4                                  0.372685
# ..                                      ...
# 94                                 0.262276
# 95                                 0.258744
# 96                                 0.256355
# 97                                 0.260490
# 98                                 0.257954
#
#     raw_trans_004_temp_00_p20_batch02_roi_1  \
# 0                                  0.374105
# 1                                  0.373492
# 2                                  0.373957
# 3                                  0.380127
# 4                                  0.383596
# ..                                      ...
# 94                                 0.218845
# 95                                 0.216869
# 96                                 0.217401
# 97                                 0.221056
# 98                                 0.216388
#
#     raw_trans_004_temp_00_p20_batch02_roi_2  \
# 0                                  0.352990
# 1                                  0.351859
# 2                                  0.358376
# 3                                  0.359230
# 4                                  0.362091
# ..                                      ...
# 94                                 0.203801
# 95                                 0.205301
# 96                                 0.202441
# 97                                 0.201092
# 98                                 0.198977
#
#     raw_trans_004_temp_00_p20_batch02_roi_3  \
# 0                                  0.331936
# 1                                  0.339384
# 2                                  0.338955
# 3                                  0.337304
# 4                                  0.340195
# ..                                      ...
# 94                                 0.178403
# 95                                 0.180948
# 96                                 0.175774
# 97                                 0.176913
# 98                                 0.172026
#
#     raw_trans_004_temp_00_p20_batch02_roi_4  \
# 0                                  0.334714
# 1                                  0.339501
# 2                                  0.347221
# 3                                  0.349868
# 4                                  0.349395
# ..                                      ...
# 94                                 0.186018
# 95                                 0.186236
# 96                                 0.181470
# 97                                 0.184806
# 98                                 0.181828
#
#     raw_trans_005_temp_00_p20_batch03_roi_1  \
# 0                                  0.320329
# 1                                  0.318983
# 2                                  0.325476
# 3                                  0.325429
# 4                                  0.325452
# ..                                      ...
# 94                                 0.171361
# 95                                 0.165841
# 96                                 0.165128
# 97                                 0.163411
# 98                                 0.162006
#
#     raw_trans_005_temp_00_p20_batch03_roi_2  \
# 0                                  0.300212
# 1                                  0.302073
# 2                                  0.301888
# 3                                  0.300348
# 4                                  0.304406
# ..                                      ...
# 94                                 0.169776
# 95                                 0.167529
# 96                                 0.162875
# 97                                 0.164910
# 98                                 0.161325
#
#     raw_trans_005_temp_00_p20_batch03_roi_3
# 0                                  0.231471
# 1                                  0.232556
# 2                                  0.234210
# 3                                  0.235793
# 4                                  0.238790
# ..                                      ...
# 94                                 0.108529
# 95                                 0.110203
# 96                                 0.103607
# 97                                 0.103579
# 98                                 0.102790
#
# [99 rows x 12 columns]

# %%
h2o = {'abbv': 'H2O','composition' : {'H':2.0, 'O':1.0},'density':0.997, 'thickness': 0.3}
ec = {'abbv': 'EC', 'composition' : {'C':3.0, 'H':4.0, 'O':3.0},'density':1.32, 'thickness': 0.3}
dmc = {'abbv': 'DMC','composition' : {'C':3.0, 'H':6.0, 'O':3.0}, 'density':1.07, 'thickness': 0.3}
dec = {'abbv': 'DEC','composition' : {'C':5.0, 'H':10.0, 'O':3.0}, 'density':0.975, 'thickness': 0.3}
lipf6 = {'abbv': 'LiPF6','composition' : {'LI':1.0, 'P':1.0, 'F':6.0}, 'density':1.5, 'thickness': 0.3}
ec_dmc_11v = {'abbv': 'EC_DMC (1:1v)','molecules' : [ec,0.5,dmc,0.5], 'density':1.28, 'thickness': 0.3 }
ec_dmc_11w = {'abbv': 'EC_DMC (1:1w)','molecules' : [ec,0.447511501,dmc,0.552488499], 'density':1.2335, 'thickness': 0.3 }
ec_dec_11v = {'abbv': 'EC_DEC (1:1v)','molecules' : [ec,0.5,dec,0.5], 'density':1.1785, 'thickness': 0.3 }
ec_dec_37w = {'abbv': 'EC_DEC (3:7w)','molecules' : [ec,0.240305619,dec,0.759694381], 'density':1.0705, 'thickness': 0.3 }
lp30 = {'abbv': 'LP30','molecules' : [ec, 0.406359477,dmc, 0.501683056, lipf6, 0.091957467], 'density':1.2795, 'thickness': 0.3}
lp40 = {'abbv': 'LP40','molecules' : [ec, 0.447925137,dec, 0.447925137, lipf6, 0.104149725], 'density':1.2635, 'thickness': 0.3}
lp47 = {'abbv': 'LP47','molecules' : [ec, 0.218207723,dec, 0.689834809, lipf6 ,0.091957467], 'density':1.1685, 'thickness': 0.3}
ec_dec_sol = {'abbv': 'EC_DEC (sol)','molecules' : [ec,0.5,dec,0.5], 'density':1.1785, 'thickness': 0.3 }
pe = {'abbv': 'PE', 'composition' : {'C':1.0, 'H':2.0},'density':0.92, 'thickness': 0.2}

# %%
compounds_dict = [lp30,lp40,lp47,ec,ec_dmc_11v,ec_dec_11v, ec_dec_37w,dmc,dec,pe,h2o]

# %% [markdown]
# Function to get the cross sections, the requested_cs is a list of the desired cross-sections oprions are ['total_cs','h_cs','lli_cs']

# %%
requested_cs = ['h_cs']
cs_table = get_cross_sections (raw_trans_val, raw_trans_val_casing, compounds_dict, requested_cs , 
                               dst_dir = src_dir, save_table = True, name_xlsx = 'BOA_p20_CS_results.xlsx')

# %%
print(cs_table)
# Out:
#     Wavelength [Å]  CS_H_in_LP30  CS_H_in_LP40  CS_H_in_LP47  CS_H_in_EC  \
# 0         0.130658     74.653925     74.507664     71.958437   76.256996
# 1         0.188728     73.268745     72.805912     70.821899   75.850478
# 2         0.246798     71.585088     72.626019     70.568057   74.131022
# 3         0.304869     71.700407     72.438836     71.137553   76.156167
# 4         0.362939     70.991458     71.525187     70.260577   75.366567
# ..             ...           ...           ...           ...         ...
# 94        6.409675    117.371544    115.832857    115.888325  106.164390
# 95        6.467745    117.607817    116.339991    117.367482  107.130611
# 96        6.525816    118.762861    118.007230    117.122950  107.704536
# 97        6.583886    118.373468    119.096317    117.783319  106.259554
# 98        6.641956    118.063359    116.660887    118.451906  106.476225
#
#     CS_H_in_EC_DMC (1:1v)  CS_H_in_EC_DEC (1:1v)  CS_H_in_EC_DEC (3:7w)  \
# 0               69.028963              68.188264              67.735386
# 1               68.682023              67.990722              65.729503
# 2               68.654972              66.636685              65.886691
# 3               67.891554              67.019961              66.762054
# 4               67.042479              66.327547              66.079404
# ..                    ...                    ...                    ...
# 94             113.163562             109.871222             111.517532
# 95             113.672312             109.065784             110.285048
# 96             113.211862             109.922310             112.154181
# 97             111.839166             110.473311             111.721728
# 98             113.016944             110.721293             113.205256
#
#     CS_H_in_DMC  CS_H_in_DEC  CS_H_in_PE  CS_H_in_H2O
# 0     72.749887    65.944214  136.940128    66.139184
# 1     71.200226    65.840761  135.429506    65.617752
# 2     69.525825    64.551351  135.623906    65.309457
# 3     69.504040    65.051595  137.197691    65.338579
# 4     69.533226    64.981358  135.377202    64.658701
# ..          ...          ...         ...          ...
# 94   117.613584   107.273909  209.800294   104.033915
# 95   117.290798   109.269709  211.140765   103.127083
# 96   119.074670   109.361701  214.365932   106.073718
# 97   117.695294   110.093541  212.883900   106.117928
# 98   118.387598   110.181786  214.770842   106.141939
#
# [99 rows x 12 columns]
